# %%
#import libraries:

import os
import seaborn as sns
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import ListedColormap, BoundaryNorm
from matplotlib.ticker import FormatStrFormatter

# %%
#use the csv sheets provided or fredapi library to get the data of economic factors:
#currently there are 11 features in the drive, you can add any other features which you feel are suitable in detecing the regimes:


csv_lst=list(os.walk('FredData'))[0][2]
itemList=[pd.read_csv('FredData/'+file_name,keep_default_na=True,na_values='.') for file_name in csv_lst]

# %%
#put them to a list, clear NA values
for i in range(len(itemList)):
    itemList[i]=itemList[i].dropna(axis=0,how='any') 
    itemList[i].columns=['Date', csv_lst[i][5:-4]]

# %%
#Preprocessing, use appropriate methods to fill the missing values in the data:
#upsample and interpolate to get the daily data 

sample=itemList[0]

def interpolateAsDaily(data):
    daily_data=data.set_index('Date').resample('D').mean().ffill()
    return daily_data

for i in range(len(itemList)):
    itemList[i]['Date']=pd.to_datetime(itemList[i]['Date'])
    itemList[i]=interpolateAsDaily(itemList[i]) 



# new_all.to_csv('./all.csv')

# %%
#group all the data
new_all = itemList[0]
for i in itemList[1:]:
    new_all = pd.merge(new_all, i, on = 'Date')
    
new_all
# Out:
#                 BASE   CIVPART        CP  CPIAUCSL  CPILFESL  DCOILWTICO  \
# Date
# 2003-01-03  0.002341  0.001508 -0.004950  0.001653  0.001042    0.040350
# 2003-01-04  0.002341  0.001508 -0.004950  0.001653  0.001042    0.040350
# 2003-01-05  0.002341  0.001508 -0.004950  0.001653  0.001042    0.040350
# 2003-01-06  0.002341  0.001508 -0.004950  0.001653  0.001042   -0.029164
# 2003-01-07  0.002341  0.001508 -0.004950  0.001653  0.001042   -0.033757
# ...              ...       ...       ...       ...       ...         ...
# 2019-12-14  0.003477  0.001582  0.020875  0.001877  0.001668    0.015715
# 2019-12-15  0.003477  0.001582  0.020875  0.001877  0.001668    0.015715
# 2019-12-16  0.003477  0.001582  0.020875  0.001877  0.001668    0.001664
# 2019-12-17  0.003477  0.001582  0.020875  0.001877  0.001668    0.011128
# 2019-12-18  0.019342  0.001582  0.020875  0.001877  0.001668    0.000821
#
#                  DFF     DGS10     DGS30      DGS5  ...   PSAVERT     RRSFS  \
# Date                                                ...
# 2003-01-03 -0.138462 -0.004914  0.000000 -0.006557  ...  0.000000  0.000025
# 2003-01-04  0.000000 -0.004914  0.000000 -0.006557  ...  0.000000  0.000025
# 2003-01-05  0.000000 -0.004914  0.000000 -0.006557  ...  0.000000  0.000025
# 2003-01-06  0.089286  0.009877  0.003861  0.023102  ...  0.000000  0.000025
# 2003-01-07 -0.016393 -0.012225 -0.003846 -0.019355  ...  0.000000  0.000025
# ...              ...       ...       ...       ...  ...       ...       ...
# 2019-12-14  0.000000 -0.042105 -0.025862 -0.040462  ... -0.026667  0.000182
# 2019-12-15  0.000000 -0.042105 -0.025862 -0.040462  ... -0.026667  0.000182
# 2019-12-16  0.006452  0.038462  0.017699  0.036145  ... -0.026667  0.000182
# 2019-12-17 -0.006410  0.000000  0.004348 -0.005814  ... -0.026667  0.000182
# 2019-12-18  0.000000  0.015873  0.017316  0.017544  ... -0.026667  0.000182
#
#               STLFSI    T10YIE     T5YIE    T5YIFR       TCU   TEDRATE  \
# Date
# 2003-01-03  0.003160 -0.012195 -0.015385 -0.010101  0.008547  0.055556
# 2003-01-04  0.003160 -0.012195 -0.015385 -0.010101  0.008547  0.055556
# 2003-01-05  0.003160 -0.012195 -0.015385 -0.010101  0.008547  0.055556
# 2003-01-06  0.003160  0.006173  0.023438 -0.005102  0.008547  0.052632
# 2003-01-07  0.003160 -0.006135 -0.022901  0.005128  0.008547  0.100000
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-14  0.013585 -0.011628  0.000000 -0.021978 -0.003914  0.000000
# 2019-12-15  0.013585 -0.011628  0.000000 -0.021978 -0.003914  0.000000
# 2019-12-16  0.013585  0.017647  0.012346  0.022472 -0.003914  0.000000
# 2019-12-17  0.013585  0.011561  0.006098  0.016484 -0.003914  0.027778
# 2019-12-18  0.013585  0.005714  0.018182 -0.005405 -0.003914  0.027027
#
#                TOTCI  UNEMPLOY
# Date
# 2003-01-03 -0.006815  0.014085
# 2003-01-04 -0.006815  0.014085
# 2003-01-05 -0.006815  0.014085
# 2003-01-06 -0.006815  0.014085
# 2003-01-07 -0.006815  0.014085
# ...              ...       ...
# 2019-12-14  0.000872 -0.008361
# 2019-12-15  0.000872 -0.008361
# 2019-12-16  0.000872 -0.008361
# 2019-12-17  0.000872 -0.008361
# 2019-12-18 -0.000233 -0.008361
#
# [6194 rows x 50 columns]

# %%
#split the data

datasets = new_all.iloc[:, 1:]

#feature scaling
sc_X = StandardScaler()
X_Train = sc_X.fit_transform(datasets)
#X_Test = sc_X.transform(X_Test)

X_c = pd.DataFrame(X_Train)
X_c.columns = [i for i in range(X_c.shape[1])]

# %%
#conduct PCA analysis on the processed data:

pca = PCA(n_components = 4)
newData = pca.fit_transform(new_all)
print(sum(pca.explained_variance_ratio_))
# Out:
# 0.9602150884189301

# %%
#additional task:once the PCA is conducted apply any clusterting techniques to find regimes:

scores = []
for k in range(2, 10):
    estimator = KMeans(n_clusters=k)
    estimator.fit(newData)
    scores.append(silhouette_score(newData, estimator.labels_, metric='euclidean'))
x = range(2, 10)
plt.xlabel('k')
plt.ylabel('Silhouette Coefficient')
plt.plot(x, scores, '*-')
plt.show()

# %%
sse = []
for k in range(1, 9):
    estimator = KMeans(n_clusters=k)
    estimator.fit(newData)
    sse.append(estimator.inertia_)
x = range(1, 9)
plt.xlabel('k')
plt.ylabel('SSE')
plt.plot(x, sse, '*-')
plt.show()

# %%
data1=new_all.reset_index()
datetime = data1['Date']

X_Train = pd.DataFrame(trainData)

res = kmeans.labels_
res_seri = pd.Series(res)

new_all = pd.concat([datetime, X_Train, classRes], axis = 1)
new_all.columns = ['DATE', 'PC1', 'PC2', 'PC3', 'PC4', 'Cluster']
print(new_all)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19536/3814581193.py in <module>
#       7 res_seri = pd.Series(res)
#       8
# ----> 9 new_all = pd.concat([datetime, X_Train, classRes], axis = 1)
#      10 new_all.columns = ['DATE', 'PC1', 'PC2', 'PC3', 'PC4', 'Cluster']
#      11 print(new_all)
#
# NameError: name 'classRes' is not defined

# %%
#fit a K-means model

kmeans = KMeans(n_clusters =10)
kmeans.fit(newData)
classRes = pd.DataFrame(kmeans.fit_predict(newData))

res = kmeans.labels_
res_seri = pd.Series(res)
res_seri.index=new_all.index


trainData = pd.concat([pd.DataFrame(newData,index=new_all.index), res_seri], axis = 1)
trainData.columns = [ 'PC1', 'PC2', 'PC3', 'PC4', 'Cluster']
trainData.index=new_all.index
trainData
# Out:
#                  PC1       PC2       PC3       PC4  Cluster
# Date
# 2003-01-03 -0.389469 -0.032304  0.017910 -0.002237        0
# 2003-01-04 -0.389576 -0.032298  0.019396 -0.004162        0
# 2003-01-05 -0.389730 -0.032326  0.019506 -0.003840        0
# 2003-01-06 -0.390309 -0.032184  0.012602 -0.007587        0
# 2003-01-07 -0.391164 -0.032197 -0.000222 -0.003012        0
# ...              ...       ...       ...       ...      ...
# 2019-12-14  0.033309 -0.029869 -0.002821 -0.039901        0
# 2019-12-15  0.033091 -0.029915 -0.002627 -0.039547        0
# 2019-12-16  0.033007 -0.029766 -0.007498 -0.040524        0
# 2019-12-17  0.032344 -0.029771 -0.016551 -0.039942        0
# 2019-12-18 -0.051777 -0.032429 -0.003594 -0.039973        0
#
# [6194 rows x 5 columns]

# %%
# Out:
#                  PC1       PC2       PC3       PC4  Cluster
# Date
# 2003-01-03 -0.389469 -0.032304  0.017910 -0.002237        1
# 2003-01-04 -0.389576 -0.032298  0.019396 -0.004162        1
# 2003-01-05 -0.389730 -0.032326  0.019506 -0.003840        1
# 2003-01-06 -0.390309 -0.032184  0.012602 -0.007587        1
# 2003-01-07 -0.391164 -0.032197 -0.000222 -0.003012        1
# ...              ...       ...       ...       ...      ...
# 2019-12-14  0.033309 -0.029869 -0.002821 -0.039901        1
# 2019-12-15  0.033091 -0.029915 -0.002627 -0.039547        1
# 2019-12-16  0.033007 -0.029766 -0.007498 -0.040524        1
# 2019-12-17  0.032344 -0.029771 -0.016551 -0.039942        1
# 2019-12-18 -0.051777 -0.032429 -0.003594 -0.039973        1
#
# [6194 rows x 5 columns]

# %%
import matplotlib.ticker as mticker

fig, axs = plt.subplots(4, 1, sharex=True, sharey=True)

cmap = plt.get_cmap('Set1')
norm = BoundaryNorm([0, 1, 2, 3, 4, 5], cmap.N)
x = np.array(range(241))
new_all=trainData
cluster = new_all['Cluster']

for i in range(4):
    
    y = new_all['PC'+str(i+1)]

    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)

    lc = LineCollection(segments, cmap=cmap, norm=norm)
    lc.set_array(cluster)
    lc.set_linewidth(2)
    line = axs[i].add_collection(lc)
    fig.colorbar(line, ax=axs[i])


xlabels = axs[0].get_xticks().tolist()
axs[0].xaxis.set_major_locator(mticker.FixedLocator(xlabels))
axs[0].xaxis.set_ticks(range(0,241,60))
axs[0].xaxis.set_ticklabels(data1['Date'][0:241:60])
axs[0].set_xlim(x.min(), x.max())
axs[0].set_ylim(-0.1, 0.1)

plt.show()
# Out:
# C:\Users\Robert\AppData\Local\Temp/ipykernel_19536/4101278464.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   points = np.array([x, y]).T.reshape(-1, 1, 2)

# %%
#split the data into train and test:
data=pd.read_csv("train_till201312.csv")
data2=pd.read_csv("test_till2019.csv")

x_train=data.iloc[:,2:-2].values
y_train=data.iloc[:,-1].values
x_test=data2.iloc[:,2:-2].values
y_test=data2.iloc[:,-1].values

# %%
#train the data using stats libraries by applying decision tree and find the accuracy on the test data:
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import numpy as np
from io import StringIO
import pydotplus

# dt=DecisionTreeClassifier(criterion='entropy',max_depth=None,min_samples_leaf=1,ccp_alpha=0.02)
dt=DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_leaf=100,ccp_alpha=0.02)
dt.fit(x_train,y_train)

train_pre = dt.predict(x_train)
test_pre = dt.predict(x_test)

train_error = np.mean((train_pre!=y_train))
test_error = np.mean((test_pre!=y_test))
print(test_error)


feature_names = ['PC1', 'PC2', 'PC3','PC4']
target_names = ['1', '2','3','4','5']
dot_data = StringIO()
tree.export_graphviz(dt,
                     out_file=dot_data,
                     feature_names=feature_names,
                     class_names=target_names,
                     filled=True, 
                     rounded=True,
                     special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_pdf("default.pdf")

# %%
set(list(y_test))

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np


y_pred = test_pre
y_true = y_test

def plot_confusion_matrix(cm, labels, title='Confusion Matrix'):
    plt.imshow(cm, interpolation='nearest', cmap='Blues')
    plt.title(title)
    plt.colorbar()
    xlocations = np.array(range(len(labels)))
    plt.xticks(xlocations, labels, rotation=90)
    plt.yticks(xlocations, labels)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
 
 
label = ["1", "3", "4"]
tick_marks = np.array(range(len(label))) + 0.5

 
cm = confusion_matrix(y_true, y_pred)
np.set_printoptions(precision=2)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print(cm_normalized)
plt.figure(figsize=(12, 8), dpi=120)
 
ind_array = np.arange(len(label))
x, y = np.meshgrid(ind_array, ind_array)
 
for x_val, y_val in zip(x.flatten(), y.flatten()):
    c = cm_normalized[y_val][x_val]
    if c > 0.0:
        plt.text(x_val, y_val, "%0.2f" % (c,), color='red', fontsize=17, va='center', ha='center')
 
# offset the tick
plt.gca().set_xticks(tick_marks, minor=True)
plt.gca().set_yticks(tick_marks, minor=True)
plt.gca().xaxis.set_ticks_position('none')
plt.gca().yaxis.set_ticks_position('none')
plt.grid(True, which='minor', linestyle='-')
plt.gcf().subplots_adjust(bottom=0.15)
 
plot_confusion_matrix(cm_normalized, label, title='Normalized confusion matrix')
# plt.savefig('../Data/confusion_matrix.png', format='png')
plt.show()

# %%
# pca = PCA(n_components = 4)
f(alpha[-1])
test_error
for i in range(50):
    (train_error[i],test_error[i])=f(alpha[i])
test_error

# %%
data2

# %%
alpha=np.linspace(0,10,50)
def f(alpha):
    dt=DecisionTreeClassifier(criterion='gini',max_depth=None,min_samples_leaf=100,ccp_alpha=alpha)
    dt.fit(x_train,y_train)

    train_pre = dt.predict(x_train)
    test_pre = dt.predict(x_test)

    train_error = np.mean((train_pre!=y_train))
    test_error = np.mean((test_pre!=y_test))
    return train_error,test_error

train_error=[0]*50
test_error=[0]*50

for i in range(50):
    train_error[i],test_error[i]=f(alpha[i])
    train_error[i],test_error[i]=1-train_error[i],1-test_error[i]

    
plt.plot(alpha,train_error)
plt.plot(alpha,test_error)
    
plt.title("loss")
plt.xlabel("ccp_alpha")
plt.ylabel("accuracy rate")
plt.legend(['train', "test"], loc=0, ncol=1)
plt.show()

# %%
import graphviz

dot_data = tree.export_graphviz(dt, out_file=None,
                    feature_names=iris.feature_names,
                    class_names=iris.target_names,
                    filled=True, rounded=True,
                    special_characters=True)

graph = graphviz.Source(dot_data)  
graph

# %%
C:\Program Files\Graphviz

# %%
from sklearn.tree import export_graphviz 
import graphviz 
dot_data = export_graphviz(dt, out_file=None, class_names=['0', '1','2','3','4']) 
# graph = graphviz.Source(dot_data)

# %%
import os 
# 以下这两行是手动进行环境变量配置，防止在本机的环境变量部署失败 
os.environ['PATH'] = os.pathsep + r'C:\Program Files\Graphviz\bin'

# %%
dot_data
